# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 =pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 327.4+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df1.index.values
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
df.rename({'Indicator':'Indicator id'},axis=1)
# Out:
#                                          Indicator id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %%
df.rename({'Indicator':'Indicator id'},inplace=True,axis=1) 
df
# Out:
#                                          Indicator id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %%
df.rename({'Indicator':'Indicator id','WHO region':'WHO REGION'},axis=1)
# Out:
#                                          Indicator id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %%
df.sort_values(by=['Year'])
# Out:
#                                          Indicator id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1270                 Life expectancy at birth (years)      Published  1990
# 3193                 Life expectancy at birth (years)      Published  1990
# 3194                 Life expectancy at birth (years)      Published  1990
# 3197                Life expectancy at age 60 (years)      Published  1990
# 1264                 Life expectancy at birth (years)      Published  1990
# 3199                Life expectancy at age 60 (years)      Published  1990
# 1262                Life expectancy at age 60 (years)      Published  1990
# 1259                 Life expectancy at birth (years)      Published  1990
# 3203                Life expectancy at age 60 (years)      Published  1990
# 1273                Life expectancy at age 60 (years)      Published  1990
# ...

# %%
df.sort_values(by=['Country','Year','WHO region'])
# Out:
#                                          Indicator id PUBLISH STATES  Year  \
# 554                  Life expectancy at birth (years)      Published  1990
# 555                 Life expectancy at age 60 (years)      Published  1990
# 965                  Life expectancy at birth (years)      Published  1990
# 1395                Life expectancy at age 60 (years)      Published  1990
# 1792                 Life expectancy at birth (years)      Published  1990
# 2959                Life expectancy at age 60 (years)      Published  1990
# 146                  Life expectancy at birth (years)      Published  2000
# 147                 Life expectancy at age 60 (years)      Published  2000
# 967                 Life expectancy at age 60 (years)      Published  2000
# 1393                 Life expectancy at birth (years)      Published  2000
# 1396                Life expectancy at age 60 (years)      Published  2000
# ...

# %%
list_col= list(df.columns.values)
new_list = [ 'Country','Indicator id', 'PUBLISH STATES', 'Year', 'WHO region', 'World Bank income group','Sex', 'Display Value', 'Numeric', 'Low', 'High', 'Comments']
df = df[new_list]
df
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 5                    Antigua and Barbuda
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 12                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# ...

# %%
df['WHO region'].values
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
print(df.iloc[11])
print(df.iloc[24])
print(df.iloc[37])
# Out:
# Country                                             Austria
# Indicator id               Life expectancy at birth (years)
# PUBLISH STATES                                    Published
# Year                                                   2012
# WHO region                                           Europe
# World Bank income group                         High-income
# Sex                                                  Female
# Display Value                                            83
# Numeric                                                  83
# Low                                                     NaN
# High                                                    NaN
# Comments                                                NaN
# Name: 11, dtype: object
# Country                                    Brunei Darussalam
# Indicator id               Life expectancy at age 60 (years)
# PUBLISH STATES                                     Published
# ...

# %%
df.drop(index=[5,12,23,56])
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# 22                     Brunei Darussalam
# 24                     Brunei Darussalam
# ...

# %%
users_df=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
users_df.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
session_df=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
session_df.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
products_df=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
products_df.head()
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transaction_df=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')
transaction_df
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
new_df=transaction_df.merge(users_df, left_on='UserID', right_on='UserID', how='left')
new_df
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21      7          2         1       NaN
# 1              2      2011-05-26      3          4         1  Caroline
# 2              3      2011-06-16      3          3         1  Caroline
# 3              4      2012-08-26      1          2         3   Charles
# 4              5      2013-06-06      2          4         1     Pedro
# 5              6      2013-12-23      2          5         6     Pedro
# 6              7      2013-12-30      3          4         1  Caroline
# 7              8      2014-04-24    NaN          2         3       NaN
# 8              9      2015-04-24      7          4         3       NaN
# 9             10      2016-05-08      3          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %%
nan_df=new_df[new_df['User'].isnull()]
nan_df
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity User Gender  \
# 0              1      2010-08-21      7          2         1  NaN    NaN
# 7              8      2014-04-24    NaN          2         3  NaN    NaN
# 8              9      2015-04-24      7          4         3  NaN    NaN
#
#   Registered Cancelled
# 0        NaN       NaN
# 7        NaN       NaN
# 8        NaN       NaN

# %%
transaction_df.merge(users_df, left_on='UserID', right_on='UserID', how='inner')
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26      3          4         1  Caroline
# 1              3      2011-06-16      3          3         1  Caroline
# 2              7      2013-12-30      3          4         1  Caroline
# 3             10      2016-05-08      3          4         4  Caroline
# 4              4      2012-08-26      1          2         3   Charles
# 5              5      2013-06-06      2          4         1     Pedro
# 6              6      2013-12-23      2          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
transaction_df.merge(users_df, left_on='UserID', right_on='UserID', how='outer')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %%
users_df.merge(session_df, left_on='Registered', right_on='SessionDate', how='inner')
# Out:
#    UserID_x      User  Gender  Registered   Cancelled  SessionID SessionDate  \
# 0         1   Charles    male  2012-12-21         NaN          7  2012-12-21
# 1         2     Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 2         3  Caroline  female  2012-10-23  2016-06-07          6  2012-10-23
# 3         4   Brielle  female  2013-07-17         NaN          9  2013-07-17
# 4         5  Benjamin    male  2010-11-25         NaN          3  2010-11-25
#
#    UserID_y
# 0         3
# 1         2
# 2         4
# 3         4
# 4         2

# %%
index = pd.MultiIndex.from_product([users_df.UserID,products_df.ProductID], names = ["UserID", "ProductID"])
cross_df = pd.DataFrame(index = index).reset_index()
cross_df
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
qlist=[]
for x in range(1,6):
    for y in range(1,6):
        if(transaction_df[(transaction_df['UserID']==x)&(transaction_df['ProductID']==y)].empty):
            qlist.append(0)
        else:
            qlist.append(transaction_df[(transaction_df['UserID']==x)&(transaction_df['ProductID']==y)].Quantity.values.sum())
cross_df["Quantity"]=qlist 
cross_df
# Out:
#     UserID  ProductID  Quantity
# 0        1          1         0
# 1        1          2         3
# 2        1          3         0
# 3        1          4         0
# 4        1          5         0
# 5        2          1         0
# 6        2          2         0
# 7        2          3         0
# 8        2          4         1
# 9        2          5         6
# 10       3          1         0
# 11       3          2         0
# 12       3          3         1
# 13       3          4         6
# 14       3          5         0
# 15       4          1         0
# 16       4          2         0
# 17       4          3         0
# 18       4          4         0
# 19       4          5         0
# 20       5          1         0
# 21       5          2         0
# 22       5          3         0
# 23       5          4         0
# 24       5          5         0

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())
nw_df=pysqldf('''SELECT * FROM ( SELECT * FROM transaction_df ORDER BY TransactionDate desc) as temp GROUP BY temp.UserID;''')
nw_df
nw1_df=nw_df.dropna()
nw2_df=nw1_df[nw1_df['UserID']<6]
nw2_df
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 1              4      2012-08-26     1.0          2         3
# 2              5      2013-06-06     2.0          4         1
# 3              2      2011-05-26     3.0          4         1

# %%
users_df.merge(nw2_df, left_on='UserID',right_on='UserID',how='left')
# Out:
#   UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0      1   Charles    male  2012-12-21         NaN            4.0
# 1      2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2      3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3      4   Brielle  female  2013-07-17         NaN            NaN
# 4      5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %%
my_columns = list(new_df.columns)
print(my_columns)
# Out:
# ['TransactionID', 'TransactionDate', 'UserID', 'ProductID', 'Quantity', 'User', 'Gender', 'Registered', 'Cancelled']

# %%
missing_info = list(new_df.columns[new_df.isnull().any()])
for col in missing_info:
    num_missing = new_df[new_df[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, num_missing))
# Out:
# number missing for column UserID: 1
# number missing for column User: 3
# number missing for column Gender: 3
# number missing for column Registered: 3
# number missing for column Cancelled: 4

# %%
for col in missing_info:
    percent_missing = new_df[new_df[col].isnull() == True].shape[0] / new_df.shape[0]
    print('percent missing for column {}: {}'.format(col, percent_missing))
# Out:
# percent missing for column UserID: 0.1
# percent missing for column User: 0.3
# percent missing for column Gender: 0.3
# percent missing for column Registered: 0.3
# percent missing for column Cancelled: 0.4
