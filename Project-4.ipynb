# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as plt
import pylab as py
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# # DataSet

# %%
train_data=pd.read_csv('f:/Downloads/data_stocks.csv')

# %%
train_data.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN    ...     NYSE.WYN  \
# 0    102.2300      85.2200       59.760       121.52    ...       84.370
# 1    102.1400      85.6500       59.840       121.48    ...       84.370
# 2    102.2125      85.5100       59.795       121.93    ...       84.585
# 3    102.1400      85.4872       59.620       121.44    ...       84.460
# 4    102.0600      85.7001       59.620       121.60    ...       84.470
#
#    NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  \
# ...

# %% [markdown]
# # Implementation of Principal Component Analysis

# %%
pca=PCA(n_components=3)
pca.fit(train_data)
x_red=pca.transform(train_data)
x_red.shape
# Out:
# (41266, 3)

# %%
x_red
# Out:
# array([[ 6.52248168e+06,  1.11716697e+02,  7.22358105e+01],
#        [ 6.52242168e+06,  1.06254065e+02,  7.25607707e+01],
#        [ 6.52236168e+06,  1.04834983e+02,  7.01535143e+01],
#        ...,
#        [-6.46079833e+06,  1.13712989e+02, -4.41729048e+01],
#        [-6.46085833e+06,  1.14430644e+02, -4.37273358e+01],
#        [-6.46091833e+06,  1.12455756e+02, -4.50708462e+01]])

# %%
py.scatter(x_red[:,0],x_red[:,1],cmap='RdYlBu')
py.show()

# %% [markdown]
# # Implementation of Kmeans for Actual Dataset

# %%
k_means=KMeans(n_clusters=3,random_state=0)
k_means.fit(train_data)
y_pred=k_means.predict(train_data)

# %% [markdown]
# # Applying Cluster to the reduced Data (PCA Data)

# %%
py.scatter(x_red[:,0],x_red[:,1],c=y_pred,cmap='RdYlBu')

# %% [markdown]
# # Cluster view of NASDAQ.AAL VS NASDAQ.AAPL

# %%
py.figure(figsize=(18,9))
py.scatter(train_data['NASDAQ.AAL'],train_data['NASDAQ.AAPL'],c=y_pred,cmap='RdYlBu')
py.xlabel('NASDAQ.AAL')
py.ylabel('NASDAQ.AAPL')
# Out:
# Text(0,0.5,'NASDAQ.AAPL')

# %% [markdown]
# # Cluster view of NASDAQ.AAL VS NASDAQ.ADBE

# %%
py.figure(figsize=(18,9))
py.scatter(train_data['NASDAQ.AAL'],train_data['NASDAQ.ADBE'],c=y_pred,cmap='RdYlBu')
py.xlabel('NASDAQ.AAL')
py.ylabel('NASDAQ.ADBE')
# Out:
# Text(0,0.5,'NASDAQ.ADBE')

# %% [markdown]
# # Cluster view of NASDAQ.AAL VS NASDAQ.ADP

# %%
py.figure(figsize=(18,9))
py.scatter(train_data['NASDAQ.AAL'],train_data['NASDAQ.ADP'],c=y_pred,cmap='RdYlBu')
py.xlabel('NASDAQ.AAL')
py.ylabel('NASDAQ.ADP')
# Out:
# Text(0,0.5,'NASDAQ.ADP')

# %% [markdown]
# # Cluster view of NASDAQ.AAL VS NASDAQ.ADI

# %%
py.figure(figsize=(18,9))
py.scatter(train_data['NASDAQ.AAL'],train_data['NASDAQ.ADI'],c=y_pred,cmap='RdYlBu')
py.xlabel('NASDAQ.AAL')
py.ylabel('NASDAQ.ADI')
# Out:
# Text(0,0.5,'NASDAQ.ADI')

# %% [markdown]
# # VISUALIZATION OF CLUSTER CENTER

# %%
centre=k_means.cluster_centers_
py.scatter(centre[:,1],centre[:,0],c='b')

# %%
centre
# Out:
# array([[1.49325559e+09, 2.37336350e+03, 4.43766494e+01, ...,
#         6.64558575e+01, 1.19933090e+02, 5.60675651e+01],
#        [1.50193599e+09, 2.45876042e+03, 4.93216387e+01, ...,
#         7.51484971e+01, 1.19993076e+02, 6.18347926e+01],
#        [1.49742476e+09, 2.42726166e+03, 4.92559737e+01, ...,
#         7.32341053e+01, 1.24695264e+02, 6.25062306e+01]])

# %% [markdown]
# # Cluster view of NASDAQ.AAL VS NASDAQ.ALXN

# %%
py.figure(figsize=(18,9))
py.scatter(train_data['NASDAQ.AAL'],train_data['NASDAQ.ALXN'],c=y_pred,cmap='RdYlBu')
py.xlabel('NASDAQ.AAL')
py.ylabel('NASDAQ.ALXN')
# Out:
# Text(0,0.5,'NASDAQ.ADI')

# %% [markdown]
# # Cluster view of NASDAQ.AAPL VS NASDAQ.ALXN

# %%
py.figure(figsize=(18,9))
py.scatter(train_data['NASDAQ.AAPL'],train_data['NASDAQ.ALXN'],c=y_pred,cmap='RdYlBu')
py.xlabel('NASDAQ.AAL')
py.ylabel('NASDAQ.ADI')
# Out:
# Text(0,0.5,'NASDAQ.ADI')

# %% [markdown]
# # 3D VISUALIZATION

# %%
ax = Axes3D(py.figure(1, figsize=(8, 6)), elev=-150, azim=110)
ax.scatter(train_data['NASDAQ.AAL'],train_data['NASDAQ.AAPL'],train_data['NASDAQ.ADBE'], c=y_pred,s=20)
ax.set_title("3D Analysis")
ax.set_xlabel("NASDAQ.AAL")
ax.set_ylabel("NASDAQ.AAPL")
ax.set_zlabel("NASDAQ.ADBE")
py.show()

# %% [markdown]
# # FINDING THE MIMINUM CLUSTERS REQUIRED FOR BETTER RESULTS

# %%
rn=range(1,15)
cal=[KMeans(n_clusters=k).fit(train_data) for k in rn]

# %%
sill_score=[silhouette_score(train_data,cal.labels_,metric='euclidean') for e in cal[1:]] 

#Due to insufficient system condfiguration, This code was not to able to execute.As a result, below codes were also not able to execute.

# %%
plt.figure(figsize=(7,8))
plt.subplot(211)
plt.plot(rn[1:],sill_score,'b*-')
plt.xlim([1,15])
plt.grid(True)
plt.ylabel('Silhouette coeficients')
plt.plot(3,sill_score[1],'o',)markersize=12,marheredgewidth=1.5,markerfacecolor='None',markededgecolor='r')

# %%
sum_squares=[e.inertia_ for e in cal]
plt.subplot(212)
plt.plot(rng,sun_squares,'b*-')
plt.xlim([1,15])
plt.xlabel('K')
plt.ylabel('Sum of Squares')
plt.plot(3,sum_squares[2],'ro',)markersize=12,marheredgewidth=1.5,markerfacecolor='None',markededgecolor='r')
