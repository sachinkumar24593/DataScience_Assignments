# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import sklearn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate as cross_val_score
from xgboost.sklearn import XGBClassifier

# %% [markdown]
# # DataSet

# %%
train_data=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',names=['Age','Workclass','Finalweight','Education','Educationnumber','Martialstatus','Occupation','Relationship','Race','Gender','Capitalgain','Capitalloss','Workinghours','Country','Status'])
test_data=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test',names=['Age','Workclass','Finalweight','Education','Educationnumber','Martialstatus','Occupation','Relationship','Race','Gender','Capitalgain','Capitalloss','Workinghours','Country','Status'])

# %%
train_data.head()
# Out:
#    Age          Workclass  Finalweight   Education  Educationnumber  \
# 0   39          State-gov        77516   Bachelors               13
# 1   50   Self-emp-not-inc        83311   Bachelors               13
# 2   38            Private       215646     HS-grad                9
# 3   53            Private       234721        11th                7
# 4   28            Private       338409   Bachelors               13
#
#          Martialstatus          Occupation    Relationship    Race   Gender  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capitalgain  Capitalloss  Workinghours         Country  Status
# 0         2174            0            40   United-States   <=50K
# 1            0            0            13   United-States   <=50K
# 2            0            0            40   United-States   <=50K
# 3            0            0            40   United-States   <=50K
# 4            0            0            40            Cuba   <=50K

# %%
test_data.drop(0,inplace=True)
test_data.head()
# Out:
#   Age   Workclass  Finalweight      Education  Educationnumber  \
# 1  25     Private     226802.0           11th              7.0
# 2  38     Private      89814.0        HS-grad              9.0
# 3  28   Local-gov     336951.0     Assoc-acdm             12.0
# 4  44     Private     160323.0   Some-college             10.0
# 5  18           ?     103497.0   Some-college             10.0
#
#          Martialstatus          Occupation Relationship    Race   Gender  \
# 1        Never-married   Machine-op-inspct    Own-child   Black     Male
# 2   Married-civ-spouse     Farming-fishing      Husband   White     Male
# 3   Married-civ-spouse     Protective-serv      Husband   White     Male
# 4   Married-civ-spouse   Machine-op-inspct      Husband   Black     Male
# 5        Never-married                   ?    Own-child   White   Female
#
#    Capitalgain  Capitalloss  Workinghours         Country   Status
# 1          0.0          0.0          40.0   United-States   <=50K.
# 2          0.0          0.0          50.0   United-States   <=50K.
# 3          0.0          0.0          40.0   United-States    >50K.
# 4       7688.0          0.0          40.0   United-States    >50K.
# 5          0.0          0.0          30.0   United-States   <=50K.

# %% [markdown]
# # Checking null values

# %%
train_data.isna().sum()
# Out:
# Age                0
# Workclass          0
# Finalweight        0
# Education          0
# Educationnumber    0
# Martialstatus      0
# Occupation         0
# Relationship       0
# Race               0
# Gender             0
# Capitalgain        0
# Capitalloss        0
# Workinghours       0
# Country            0
# Status             0
# dtype: int64

# %%
test_data.isna().sum()
# Out:
# Age                0
# Workclass          0
# Finalweight        0
# Education          0
# Educationnumber    0
# Martialstatus      0
# Occupation         0
# Relationship       0
# Race               0
# Gender             0
# Capitalgain        0
# Capitalloss        0
# Workinghours       0
# Country            0
# Status             0
# dtype: int64

# %% [markdown]
# # Data before Cleaning

# %%
i=1
columns=list(['Workclass','Education','Educationnumber','Martialstatus','Occupation','Relationship','Race','Gender','Country', 'Status'])
for val in columns:
    plt.subplot(5,2,i)
    train_data[val].value_counts().plot(kind='bar',figsize=(20,20))
    plt.show
    i=i+1

# %%
i=1
columns=list(['Workclass','Education','Educationnumber','Martialstatus','Occupation','Relationship','Race','Gender','Country'])
for val in columns:
    plt.subplot(5,2,i)
    test_data[val].value_counts().plot(kind='bar',figsize=(20,20))
    plt.show
    i=i+1

# %% [markdown]
# # Workclass column - grouping

# %%
train_data[train_data['Workclass']==' ?']
# Out:
#        Age Workclass  Finalweight      Education  Educationnumber  \
# 27      54         ?       180211   Some-college               10
# 61      32         ?       293936        7th-8th                4
# 69      25         ?       200681   Some-college               10
# 77      67         ?       212759           10th                6
# 106     17         ?       304873           10th                6
# 128     35         ?       129305        HS-grad                9
# 149     43         ?       174662   Some-college               10
# 154     52         ?       252903        HS-grad                9
# 160     68         ?        38317        1st-4th                2
# 187     53         ?       135105      Bachelors               13
# 201     19         ?       170653        HS-grad                9
# 221     64         ?       187656        1st-4th                2
# 226     60         ?        24215           10th                6
# 243     20         ?       119156   Some-college               10
# 266     19         ?       218956   Some-college               10
# 297     39         ?       157443        Masters               14
# 312     19         ?       860348   Some-college               10
# 326     23         ?       211601      Assoc-voc               11
# 346     67         ?        36135           11th                7
# 347     30         ?       151989      Assoc-voc               11
# 354     59         ?       372020      Bachelors               13
# 397     20         ?       137300        HS-grad                9
# 408     28         ?       123147   Some-college               10
# 430     80         ?       107762        HS-grad                9
# 431     17         ?       202521           11th                7
# 449     17         ?       258872           11th                7
# 459     32         ?       115745   Some-college               10
# 471     22         ?       139883   Some-college               10
# 484     52         ?       271749           12th                8
# 486     63         ?       401531        1st-4th                2
# ...    ...       ...          ...            ...              ...
# 32016   62         ?       178764        HS-grad                9
# 32039   24         ?       108495        HS-grad                9
# 32062   26         ?       375313   Some-college               10
# 32070   18         ?        97474        HS-grad                9
# 32073   65         ?       192825        7th-8th                4
# 32075   27         ?       147638        Masters               14
# 32080   21         ?       155697            9th                5
# 32083   51         ?        43909        HS-grad                9
# 32088   21         ?        78374        HS-grad                9
# 32093   62         ?       263374      Assoc-voc               11
# 32103   34         ?       330301        7th-8th                4
# 32189   19         ?       204868        HS-grad                9
# 32201   49         ?       113913        HS-grad                9
# 32206   72         ?        96867        5th-6th                3
# 32275   20         ?        99891   Some-college               10
# 32291   59         ?       120617   Some-college               10
# 32310   21         ?       205939   Some-college               10
# 32317   63         ?       126540   Some-college               10
# 32335   18         ?       156608           11th                7
# 32343   66         ?        93318        HS-grad                9
# 32426   20         ?       203992        HS-grad                9
# 32477   49         ?       114648           12th                8
# 32490   60         ?       134152            9th                5
# 32494   82         ?       403910        HS-grad                9
# 32525   81         ?       120478      Assoc-voc               11
# 32530   35         ?       320084      Bachelors               13
# 32531   30         ?        33811      Bachelors               13
# 32539   71         ?       287372      Doctorate               16
# 32541   41         ?       202822        HS-grad                9
# 32542   72         ?       129912        HS-grad                9
#
#                 Martialstatus Occupation     Relationship  \
# 27         Married-civ-spouse          ?          Husband
# 61      Married-spouse-absent          ?    Not-in-family
# 69              Never-married          ?        Own-child
# 77         Married-civ-spouse          ?          Husband
# 106             Never-married          ?        Own-child
# 128        Married-civ-spouse          ?          Husband
# 149                  Divorced          ?    Not-in-family
# 154                  Divorced          ?    Not-in-family
# 160                  Divorced          ?    Not-in-family
# 187                  Divorced          ?    Not-in-family
# 201             Never-married          ?        Own-child
# 221                  Divorced          ?    Not-in-family
# 226                  Divorced          ?    Not-in-family
# 243             Never-married          ?        Own-child
# 266             Never-married          ?        Own-child
# 297        Married-civ-spouse          ?             Wife
# 312             Never-married          ?        Own-child
# 326             Never-married          ?        Own-child
# 346        Married-civ-spouse          ?          Husband
# 347                  Divorced          ?        Unmarried
# 354        Married-civ-spouse          ?          Husband
# 397             Never-married          ?   Other-relative
# 408        Married-civ-spouse          ?             Wife
# 430                   Widowed          ?    Not-in-family
# 431             Never-married          ?        Own-child
# 449             Never-married          ?        Own-child
# 459        Married-civ-spouse          ?          Husband
# 471             Never-married          ?        Own-child
# 484             Never-married          ?   Other-relative
# 486        Married-civ-spouse          ?          Husband
# ...                       ...        ...              ...
# 32016      Married-civ-spouse          ?          Husband
# 32039           Never-married          ?        Own-child
# 32062           Never-married          ?        Own-child
# 32070           Never-married          ?        Own-child
# 32073      Married-civ-spouse          ?          Husband
# 32075           Never-married          ?    Not-in-family
# 32080           Never-married          ?        Own-child
# 32083                Divorced          ?        Unmarried
# 32088           Never-married          ?   Other-relative
# 32093      Married-civ-spouse          ?          Husband
# 32103               Separated          ?        Unmarried
# 32189      Married-civ-spouse          ?             Wife
# 32201      Married-civ-spouse          ?             Wife
# 32206                 Widowed          ?    Not-in-family
# 32275           Never-married          ?        Own-child
# 32291           Never-married          ?    Not-in-family
# 32310           Never-married          ?        Own-child
# 32317                Divorced          ?    Not-in-family
# 32335           Never-married          ?        Own-child
# 32343                 Widowed          ?        Unmarried
# 32426           Never-married          ?        Own-child
# 32477                Divorced          ?   Other-relative
# 32490                Divorced          ?    Not-in-family
# 32494           Never-married          ?    Not-in-family
# 32525                Divorced          ?        Unmarried
# 32530      Married-civ-spouse          ?             Wife
# 32531           Never-married          ?    Not-in-family
# 32539      Married-civ-spouse          ?          Husband
# 32541               Separated          ?    Not-in-family
# 32542      Married-civ-spouse          ?          Husband
#
#                       Race   Gender  Capitalgain  Capitalloss  Workinghours  \
# 27      Asian-Pac-Islander     Male            0            0            60
# 61                   White     Male            0            0            40
# 69                   White     Male            0            0            40
# 77                   White     Male            0            0             2
# 106                  White   Female        34095            0            32
# 128                  White     Male            0            0            40
# 149                  White   Female            0            0            40
# 154                  White     Male            0            0            45
# 160                  White   Female            0            0            20
# 187                  White   Female            0            0            50
# 201                  White     Male            0            0            40
# 221                  White     Male            0            0            40
# 226     Amer-Indian-Eskimo   Female            0            0            10
# 243                  White     Male            0            0            20
# 266                  White     Male            0            0            24
# 297     Asian-Pac-Islander   Female         3464            0            40
# 312                  Black   Female            0            0            25
# 326                  Black   Female            0            0            15
# 346                  White     Male            0            0             8
# 347                  White   Female            0            0            40
# 354                  White     Male            0            0            40
# 397                  White   Female            0            0            35
# 408                  White   Female            0         1887            40
# 430                  White     Male            0            0            24
# 431                  White     Male            0            0            40
# 449                  White   Female            0            0             5
# 459                  White     Male            0            0            40
# 471                  White     Male            0            0            40
# 484                  Black     Male          594            0            40
# 486                  White     Male            0            0            35
# ...                    ...      ...          ...          ...           ...
# 32016                White     Male            0            0            40
# 32039                White     Male            0            0            40
# 32062   Asian-Pac-Islander     Male            0            0            40
# 32070                White   Female            0            0            20
# 32073                White     Male            0            0            25
# 32075                Other   Female            0            0            40
# 32080                White     Male            0            0            42
# 32083                Black   Female            0            0            40
# 32088   Asian-Pac-Islander   Female            0            0            24
# 32093                White     Male            0            0            40
# 32103                Black   Female            0            0            40
# 32189                White   Female            0            0            36
# 32201                White   Female            0            0            60
# 32206                White   Female            0            0            40
# 32275                White   Female            0            0            30
# 32291                Black   Female            0            0            40
# 32310                White     Male            0            0            40
# 32317                White   Female            0            0             5
# 32335                White   Female            0            0            25
# 32343                White   Female            0            0            40
# 32426                White     Male            0            0            40
# 32477                Black     Male            0            0            40
# 32490                Black     Male            0            0            35
# 32494                White     Male            0            0             3
# 32525                White   Female            0            0             1
# 32530                White   Female            0            0            55
# 32531   Asian-Pac-Islander   Female            0            0            99
# 32539                White     Male            0            0            10
# 32541                Black   Female            0            0            32
# 32542                White     Male            0            0            25
#
#               Country  Status
# 27              South    >50K
# 61                  ?   <=50K
# 69      United-States   <=50K
# 77      United-States   <=50K
# 106     United-States   <=50K
# 128     United-States   <=50K
# 149     United-States   <=50K
# 154     United-States    >50K
# 160     United-States   <=50K
# 187     United-States   <=50K
# 201             Italy   <=50K
# 221     United-States   <=50K
# 226     United-States   <=50K
# 243     United-States   <=50K
# 266            Canada   <=50K
# 297                 ?   <=50K
# 312     United-States   <=50K
# 326     United-States   <=50K
# 346     United-States   <=50K
# 347     United-States   <=50K
# 354     United-States    >50K
# 397     United-States   <=50K
# 408     United-States    >50K
# 430     United-States   <=50K
# 431     United-States   <=50K
# 449     United-States   <=50K
# 459     United-States   <=50K
# 471     United-States   <=50K
# 484     United-States   <=50K
# 486     United-States   <=50K
# ...               ...     ...
# 32016   United-States    >50K
# 32039   United-States   <=50K
# 32062     Philippines   <=50K
# 32070   United-States   <=50K
# 32073   United-States   <=50K
# 32075           Japan   <=50K
# 32080   United-States   <=50K
# 32083   United-States   <=50K
# 32088   United-States   <=50K
# 32093          Canada   <=50K
# 32103   United-States   <=50K
# 32189   United-States   <=50K
# 32201   United-States   <=50K
# 32206   United-States   <=50K
# 32275   United-States   <=50K
# 32291   United-States   <=50K
# 32310   United-States   <=50K
# 32317   United-States   <=50K
# 32335   United-States   <=50K
# 32343   United-States   <=50K
# 32426   United-States   <=50K
# 32477   United-States   <=50K
# 32490   United-States   <=50K
# 32494   United-States   <=50K
# 32525               ?   <=50K
# 32530   United-States    >50K
# 32531   United-States   <=50K
# 32539   United-States    >50K
# 32541   United-States   <=50K
# 32542   United-States   <=50K
#
# [1836 rows x 15 columns]

# %%
test_data[test_data['Workclass']==' ?']
# Out:
#       Age Workclass  Finalweight      Education  Educationnumber  \
# 5      18         ?     103497.0   Some-college             10.0
# 7      29         ?     227026.0        HS-grad              9.0
# 14     58         ?     299831.0        HS-grad              9.0
# 23     72         ?     132015.0        7th-8th              4.0
# 36     65         ?     191846.0        HS-grad              9.0
# 76     17         ?     165361.0           10th              6.0
# 90     41         ?      38434.0        Masters             14.0
# 101    51         ?     189762.0   Some-college             10.0
# 114    20         ?      30796.0        HS-grad              9.0
# 133    20         ?     334105.0        HS-grad              9.0
# 183    28         ?     168524.0        HS-grad              9.0
# 186    64         ?     201368.0   Some-college             10.0
# 194    79         ?      48574.0        7th-8th              4.0
# 229    25         ?     270276.0            9th              5.0
# 230    77         ?     172744.0   Some-college             10.0
# 246    39         ?     110342.0        HS-grad              9.0
# 267    61         ?     195789.0        HS-grad              9.0
# 269    21         ?      65481.0   Some-college             10.0
# 275    53         ?     237868.0        HS-grad              9.0
# 317    20         ?     318865.0   Some-college             10.0
# 332    20         ?     303121.0   Some-college             10.0
# 351    45         ?     319993.0        HS-grad              9.0
# 379    73         ?      73402.0   Some-college             10.0
# 395    41         ?     155041.0        HS-grad              9.0
# 398    63         ?     156158.0        HS-grad              9.0
# 414    22         ?     213291.0     Assoc-acdm             12.0
# 430    23         ?     192028.0   Some-college             10.0
# 435    19         ?      50626.0   Some-college             10.0
# 438    75         ?      26586.0           10th              6.0
# 471    19         ?      47235.0   Some-college             10.0
# ...    ..       ...          ...            ...              ...
# 15833  41         ?     199018.0   Some-college             10.0
# 15837  42         ?     191149.0      Bachelors             13.0
# 15840  72         ?      94268.0        HS-grad              9.0
# 15847  17         ?     246974.0           12th              8.0
# 15852  26         ?     167261.0        HS-grad              9.0
# 15857  57         ?     123632.0      Bachelors             13.0
# 15862  39         ?     238721.0      Bachelors             13.0
# 15865  39         ?     142804.0        HS-grad              9.0
# 15877  17         ?      54978.0        7th-8th              4.0
# 15880  18         ?     149017.0           12th              8.0
# 15910  41         ?     173651.0     Assoc-acdm             12.0
# 15913  68         ?     461484.0   Some-college             10.0
# 15917  24         ?      83783.0        7th-8th              4.0
# 15923  19         ?     264767.0        HS-grad              9.0
# 15925  17         ?      48610.0        HS-grad              9.0
# 15953  58         ?     226078.0           11th              7.0
# 15984  18         ?     210652.0        HS-grad              9.0
# 15989  20         ?      38032.0        HS-grad              9.0
# 15993  22         ?     216639.0   Some-college             10.0
# 16002  18         ?      20057.0   Some-college             10.0
# 16007  76         ?     239900.0        HS-grad              9.0
# 16019  21         ?     213366.0   Some-college             10.0
# 16033  56         ?     124319.0        Masters             14.0
# 16036  19         ?     455665.0        HS-grad              9.0
# 16118  21         ?     187937.0   Some-college             10.0
# 16122  61         ?     265201.0   Some-college             10.0
# 16209  21         ?     212661.0   Some-college             10.0
# 16240  73         ?     144872.0        HS-grad              9.0
# 16252  81         ?      26711.0      Assoc-voc             11.0
# 16278  64         ?     321403.0        HS-grad              9.0
#
#                 Martialstatus Occupation     Relationship  \
# 5               Never-married          ?        Own-child
# 7               Never-married          ?        Unmarried
# 14         Married-civ-spouse          ?          Husband
# 23                   Divorced          ?    Not-in-family
# 36         Married-civ-spouse          ?          Husband
# 76              Never-married          ?        Own-child
# 90         Married-civ-spouse          ?             Wife
# 101        Married-civ-spouse          ?             Wife
# 114             Never-married          ?        Own-child
# 133             Never-married          ?    Not-in-family
# 183        Married-civ-spouse          ?        Own-child
# 186        Married-civ-spouse          ?          Husband
# 194                   Widowed          ?    Not-in-family
# 229                 Separated          ?    Not-in-family
# 230        Married-civ-spouse          ?          Husband
# 246        Married-civ-spouse          ?             Wife
# 267        Married-civ-spouse          ?          Husband
# 269             Never-married          ?        Own-child
# 275        Married-civ-spouse          ?          Husband
# 317             Never-married          ?    Not-in-family
# 332             Never-married          ?        Own-child
# 351                   Widowed          ?        Unmarried
# 379        Married-civ-spouse          ?          Husband
# 395             Never-married          ?        Own-child
# 398        Married-civ-spouse          ?          Husband
# 414             Never-married          ?        Own-child
# 430             Never-married          ?        Own-child
# 435             Never-married          ?        Own-child
# 438     Married-spouse-absent          ?    Not-in-family
# 471             Never-married          ?        Own-child
# ...                       ...        ...              ...
# 15833                Divorced          ?    Not-in-family
# 15837      Married-civ-spouse          ?             Wife
# 15840      Married-civ-spouse          ?          Husband
# 15847           Never-married          ?        Own-child
# 15852                Divorced          ?    Not-in-family
# 15857           Never-married          ?    Not-in-family
# 15862                Divorced          ?        Own-child
# 15865                Divorced          ?        Unmarried
# 15877           Never-married          ?        Own-child
# 15880           Never-married          ?        Own-child
# 15910      Married-civ-spouse          ?          Husband
# 15913      Married-civ-spouse          ?          Husband
# 15917           Never-married          ?    Not-in-family
# 15923           Never-married          ?        Own-child
# 15925           Never-married          ?        Own-child
# 15953                Divorced          ?        Unmarried
# 15984           Never-married          ?        Own-child
# 15989           Never-married          ?    Not-in-family
# 15993           Never-married          ?    Not-in-family
# 16002           Never-married          ?    Not-in-family
# 16007                Divorced          ?    Not-in-family
# 16019           Never-married          ?        Own-child
# 16033      Married-civ-spouse          ?          Husband
# 16036           Never-married          ?        Own-child
# 16118           Never-married          ?   Other-relative
# 16122      Married-civ-spouse          ?          Husband
# 16209           Never-married          ?        Own-child
# 16240      Married-civ-spouse          ?          Husband
# 16252      Married-civ-spouse          ?          Husband
# 16278                 Widowed          ?   Other-relative
#
#                       Race   Gender  Capitalgain  Capitalloss  Workinghours  \
# 5                    White   Female          0.0          0.0          30.0
# 7                    Black     Male          0.0          0.0          40.0
# 14                   White     Male          0.0          0.0          35.0
# 23                   White   Female          0.0          0.0           6.0
# 36                   White     Male          0.0          0.0          40.0
# 76                   White     Male          0.0          0.0          40.0
# 90                   White   Female       7688.0          0.0          10.0
# 101                  White   Female          0.0          0.0          18.0
# 114                  White   Female          0.0          0.0          20.0
# 133                  White   Female          0.0          0.0          40.0
# 183                  White   Female          0.0          0.0          38.0
# 186                  White     Male          0.0          0.0           8.0
# 194                  White     Male          0.0          0.0          40.0
# 229                  White   Female       1055.0          0.0          40.0
# 230                  White     Male          0.0          0.0          35.0
# 246                  White   Female          0.0          0.0          50.0
# 267                  White     Male          0.0          0.0          40.0
# 269                  White   Female          0.0          0.0          30.0
# 275                  White     Male          0.0          0.0          35.0
# 317                  White     Male          0.0          0.0          40.0
# 332                  White     Male          0.0          0.0          45.0
# 351                  White   Female          0.0          0.0          40.0
# 379                  White     Male          0.0          0.0          10.0
# 395                  White   Female       3418.0          0.0          40.0
# 398                  White     Male          0.0          0.0          16.0
# 414                  White     Male          0.0          0.0          25.0
# 430                  White   Female          0.0          0.0          35.0
# 435                  Black   Female          0.0          0.0          20.0
# 438                  White   Female          0.0          0.0           5.0
# 471                  White   Female          0.0          0.0          20.0
# ...                    ...      ...          ...          ...           ...
# 15833                White     Male          0.0       1504.0          40.0
# 15837                White   Female          0.0          0.0          28.0
# 15840                White     Male          0.0          0.0           8.0
# 15847                White     Male          0.0          0.0          30.0
# 15852                White   Female          0.0          0.0          15.0
# 15857                Black   Female          0.0          0.0          35.0
# 15862                Black   Female          0.0          0.0          40.0
# 15865                White   Female          0.0          0.0          16.0
# 15877                White   Female          0.0          0.0          15.0
# 15880                White     Male          0.0          0.0          10.0
# 15910                White     Male          0.0          0.0          99.0
# 15913                White     Male          0.0       1648.0          10.0
# 15917                White   Female          0.0          0.0          25.0
# 15923                White     Male          0.0          0.0          40.0
# 15925                White     Male          0.0          0.0          14.0
# 15953                Black   Female          0.0          0.0          32.0
# 15984                White     Male          0.0          0.0          15.0
# 15989                White   Female          0.0          0.0          40.0
# 15993                White   Female          0.0       1974.0          40.0
# 16002   Asian-Pac-Islander   Female          0.0          0.0          16.0
# 16007                White   Female          0.0          0.0           3.0
# 16019                White   Female          0.0          0.0          38.0
# 16033                White     Male          0.0          0.0          40.0
# 16036                White     Male          0.0          0.0          44.0
# 16118                White   Female          0.0          0.0          52.0
# 16122                White     Male          0.0          0.0          14.0
# 16209                White   Female          0.0          0.0          30.0
# 16240                White     Male          0.0          0.0          25.0
# 16252                White     Male       2936.0          0.0          20.0
# 16278                Black     Male          0.0          0.0          40.0
#
#               Country   Status
# 5       United-States   <=50K.
# 7       United-States   <=50K.
# 14      United-States   <=50K.
# 23      United-States   <=50K.
# 36      United-States   <=50K.
# 76      United-States   <=50K.
# 90      United-States    >50K.
# 101     United-States   <=50K.
# 114     United-States   <=50K.
# 133     United-States   <=50K.
# 183     United-States    >50K.
# 186     United-States   <=50K.
# 194     United-States   <=50K.
# 229     United-States   <=50K.
# 230     United-States   <=50K.
# 246     United-States   <=50K.
# 267     United-States   <=50K.
# 269     United-States   <=50K.
# 275     United-States    >50K.
# 317     United-States   <=50K.
# 332     United-States   <=50K.
# 351            Mexico   <=50K.
# 379     United-States   <=50K.
# 395     United-States   <=50K.
# 398     United-States   <=50K.
# 414     United-States   <=50K.
# 430     United-States   <=50K.
# 435     United-States   <=50K.
# 438     United-States   <=50K.
# 471     United-States   <=50K.
# ...               ...      ...
# 15833   United-States   <=50K.
# 15837   United-States    >50K.
# 15840   United-States   <=50K.
# 15847   United-States   <=50K.
# 15852   United-States   <=50K.
# 15857   United-States   <=50K.
# 15862   United-States   <=50K.
# 15865   United-States   <=50K.
# 15877   United-States   <=50K.
# 15880   United-States   <=50K.
# 15910   United-States   <=50K.
# 15913   United-States    >50K.
# 15917   United-States   <=50K.
# 15923   United-States   <=50K.
# 15925   United-States   <=50K.
# 15953   United-States   <=50K.
# 15984   United-States   <=50K.
# 15989   United-States   <=50K.
# 15993   United-States   <=50K.
# 16002   United-States   <=50K.
# 16007   United-States   <=50K.
# 16019   United-States   <=50K.
# 16033   United-States    >50K.
# 16036   United-States   <=50K.
# 16118   United-States   <=50K.
# 16122   United-States   <=50K.
# 16209   United-States   <=50K.
# 16240          Canada   <=50K.
# 16252   United-States   <=50K.
# 16278   United-States   <=50K.
#
# [963 rows x 15 columns]

# %%
train_data['Workclass'].replace(' ?','Others',inplace=True)

# %%
test_data['Workclass'].replace(' ?','Others',inplace=True)

# %%
print(train_data['Workclass'].value_counts())
train_data.replace([' Local-gov',' State-gov',' Federal-gov'],'Goverment',inplace=True)
train_data.replace([' Self-emp-not-inc',' Self-emp-inc'],'Selfemployed',inplace=True)
train_data.replace([' Without-pay',' Never-worked'],'Unemployed',inplace=True)
print(train_data.Workclass.value_counts())
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
# Others                1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
#  Private        22696
# Goverment        4351
# Selfemployed     3657
# Others           1836
# Unemployed         21
# Name: Workclass, dtype: int64

# %%
print(test_data['Workclass'].value_counts())
test_data.replace([' Local-gov',' State-gov',' Federal-gov'],'Goverment',inplace=True)
test_data.replace([' Self-emp-not-inc',' Self-emp-inc'],'Selfemployed',inplace=True)
test_data.replace([' Without-pay',' Never-worked'],'Unemployed',inplace=True)
print(test_data.Workclass.value_counts())
# Out:
#  Private             11210
#  Self-emp-not-inc     1321
#  Local-gov            1043
# Others                 963
#  State-gov             683
#  Self-emp-inc          579
#  Federal-gov           472
#  Without-pay             7
#  Never-worked            3
# Name: Workclass, dtype: int64
#  Private        11210
# Goverment        2198
# Selfemployed     1900
# Others            963
# Unemployed         10
# Name: Workclass, dtype: int64

# %% [markdown]
# # Education column-grouping

# %%
print(train_data['Education'].value_counts()) 
train_data['Education'].replace([' Preschool',' 1st-4th'],1,inplace=True)
train_data['Education'].replace([' 5th-6th',' 7th-8th'],2,inplace=True)
train_data['Education'].replace([' 9th',' 10th',' 11th',' 12th',' HS-grad',' Some-college'],3,inplace=True)
train_data['Education'].replace([' Bachelors',' Assoc-acdm',' Assoc-voc'],4,inplace=True)
train_data['Education'].replace([' Prof-school',' Masters'],5,inplace=True)
train_data['Education'].replace(' Doctorate',6,inplace=True)
print(train_data['Education'].value_counts())
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64
# 3    20847
# 4     7804
# 5     2299
# 2      979
# 6      413
# 1      219
# Name: Education, dtype: int64

# %%
print(test_data['Education'].value_counts()) 
test_data['Education'].replace([' Preschool',' 1st-4th'],1,inplace=True)
test_data['Education'].replace([' 5th-6th',' 7th-8th'],2,inplace=True)
test_data['Education'].replace([' 9th',' 10th',' 11th',' 12th',' HS-grad',' Some-college'],3,inplace=True)
test_data['Education'].replace([' Bachelors',' Assoc-acdm',' Assoc-voc'],4,inplace=True)
test_data['Education'].replace([' Prof-school',' Masters'],5,inplace=True)
test_data['Education'].replace(' Doctorate',6,inplace=True)
print(test_data['Education'].value_counts())
# Out:
#  HS-grad         5283
#  Some-college    3587
#  Bachelors       2670
#  Masters          934
#  Assoc-voc        679
#  11th             637
#  Assoc-acdm       534
#  10th             456
#  7th-8th          309
#  Prof-school      258
#  9th              242
#  12th             224
#  Doctorate        181
#  5th-6th          176
#  1st-4th           79
#  Preschool         32
# Name: Education, dtype: int64
# 3    10429
# 4     3883
# 5     1192
# 2      485
# 6      181
# 1      111
# Name: Education, dtype: int64

# %%
edu = list(test_data['Education'].unique())
for val in edu:
    print(val,'Education number:')
    print(test_data[test_data['Education'] == val].Educationnumber.value_counts())
# Out:
# 3 Education number:
# 9.0     5283
# 10.0    3587
# 7.0      637
# 6.0      456
# 5.0      242
# 8.0      224
# Name: Educationnumber, dtype: int64
# 4 Education number:
# 13.0    2670
# 11.0     679
# 12.0     534
# Name: Educationnumber, dtype: int64
# 5 Education number:
# 14.0    934
# 15.0    258
# Name: Educationnumber, dtype: int64
# 2 Education number:
# 4.0    309
# 3.0    176
# Name: Educationnumber, dtype: int64
# 6 Education number:
# 16.0    181
# Name: Educationnumber, dtype: int64
# 1 Education number:
# 2.0    79
# 1.0    32
# Name: Educationnumber, dtype: int64

# %%
train_data.drop(['Educationnumber'], axis=1,inplace=True)
train_data.head()
# Out:
#    Age     Workclass  Finalweight  Education        Martialstatus  \
# 0   39     Goverment        77516          4        Never-married
# 1   50  Selfemployed        83311          4   Married-civ-spouse
# 2   38       Private       215646          3             Divorced
# 3   53       Private       234721          3   Married-civ-spouse
# 4   28       Private       338409          4   Married-civ-spouse
#
#            Occupation    Relationship    Race   Gender  Capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    Capitalloss  Workinghours         Country  Status
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
test_data.drop(['Educationnumber'], axis=1,inplace=True)
test_data.head()
# Out:
#   Age  Workclass  Finalweight  Education        Martialstatus  \
# 1  25    Private     226802.0          3        Never-married
# 2  38    Private      89814.0          3   Married-civ-spouse
# 3  28  Goverment     336951.0          4   Married-civ-spouse
# 4  44    Private     160323.0          3   Married-civ-spouse
# 5  18     Others     103497.0          3        Never-married
#
#            Occupation Relationship    Race   Gender  Capitalgain  Capitalloss  \
# 1   Machine-op-inspct    Own-child   Black     Male          0.0          0.0
# 2     Farming-fishing      Husband   White     Male          0.0          0.0
# 3     Protective-serv      Husband   White     Male          0.0          0.0
# 4   Machine-op-inspct      Husband   Black     Male       7688.0          0.0
# 5                   ?    Own-child   White   Female          0.0          0.0
#
#    Workinghours         Country   Status
# 1          40.0   United-States   <=50K.
# 2          50.0   United-States   <=50K.
# 3          40.0   United-States    >50K.
# 4          40.0   United-States    >50K.
# 5          30.0   United-States   <=50K.

# %% [markdown]
# This values clears shows that Education and Educationnumber columns are highly correlated.Grouping education number and working on it leads to high correlation of features. So dropping that column will nullify this problem

# %% [markdown]
# # Martialstatus-grouping

# %%
print(train_data['Martialstatus'].value_counts())
train_data['Martialstatus'].replace([' Divorced',' Separated',' Widowed',' Married-spouse-absent'],'Unsuccessfulmarriage',inplace=True)
train_data['Martialstatus'].replace([' Married-civ-spouse',' Married-AF-spouse'],'Successfulmarraige',inplace=True)
train_data['Martialstatus'].replace([' Never-married'],'Never-Married',inplace=True)
print(train_data['Martialstatus'].value_counts())
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Martialstatus, dtype: int64
# Successfulmarraige      14999
# Never-Married           10683
# Unsuccessfulmarriage     6879
# Name: Martialstatus, dtype: int64

# %%
print(test_data['Martialstatus'].value_counts())
test_data['Martialstatus'].replace([' Divorced',' Separated',' Widowed',' Married-spouse-absent'],'Unsuccessfulmarriage',inplace=True)
test_data['Martialstatus'].replace([' Married-civ-spouse',' Married-AF-spouse'],'Successfulmarraige',inplace=True)
test_data['Martialstatus'].replace([' Never-married'],'Never-Married',inplace=True)
print(test_data['Martialstatus'].value_counts())
# Out:
#  Married-civ-spouse       7403
#  Never-married            5434
#  Divorced                 2190
#  Widowed                   525
#  Separated                 505
#  Married-spouse-absent     210
#  Married-AF-spouse          14
# Name: Martialstatus, dtype: int64
# Successfulmarraige      7417
# Never-Married           5434
# Unsuccessfulmarriage    3430
# Name: Martialstatus, dtype: int64

# %% [markdown]
# # Occupation-Grouping

# %%
train_data['Occupation'].replace([' ?'],'Others',inplace=True)
print(train_data['Occupation'].value_counts())
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
# Others                1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
test_data['Occupation'].replace([' ?'],'Others',inplace=True)
print(test_data['Occupation'].value_counts())
# Out:
#  Prof-specialty       2032
#  Exec-managerial      2020
#  Craft-repair         2013
#  Sales                1854
#  Adm-clerical         1841
#  Other-service        1628
#  Machine-op-inspct    1020
# Others                 966
#  Transport-moving      758
#  Handlers-cleaners     702
#  Tech-support          518
#  Farming-fishing       496
#  Protective-serv       334
#  Priv-house-serv        93
#  Armed-Forces            6
# Name: Occupation, dtype: int64

# %% [markdown]
# # Relationship-grouping

# %%
train_data['Relationship'].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8305
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
test_data['Relationship'].value_counts()
# Out:
#  Husband           6523
#  Not-in-family     4278
#  Own-child         2513
#  Unmarried         1679
#  Wife               763
#  Other-relative     525
# Name: Relationship, dtype: int64

# %% [markdown]
# # Gender-grouping

# %%
train_data['Gender'].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: Gender, dtype: int64

# %%
test_data['Gender'].value_counts()
# Out:
#  Male      10860
#  Female     5421
# Name: Gender, dtype: int64

# %% [markdown]
# # Race-grouping

# %%
print(train_data['Race'].value_counts())
train_data['Race'].replace([' Asian-Pac-Islander',' Amer-Indian-Eskimo',' Other'],'Other',inplace=True)
print(train_data['Race'].value_counts())
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64
#  White    27816
#  Black     3124
# Other      1621
# Name: Race, dtype: int64

# %%
print(test_data['Race'].value_counts())
test_data['Race'].replace([' Asian-Pac-Islander',' Amer-Indian-Eskimo',' Other'],'Other',inplace=True)
print(test_data['Race'].value_counts())
# Out:
#  White                 13946
#  Black                  1561
#  Asian-Pac-Islander      480
#  Amer-Indian-Eskimo      159
#  Other                   135
# Name: Race, dtype: int64
#  White    13946
#  Black     1561
# Other       774
# Name: Race, dtype: int64

# %% [markdown]
# # Country-grouping

# %%
print(train_data['Country'].value_counts())
#NorthAmerica
train_data['Country'].replace([' United-States',' Mexico',' Canada',' Puerto-Rico',' El-Salvador',' Cuba',' Jamaica',' Dominican-Republic',' Guatemala',' Haiti',' Nicaragua',' Outlying-US(Guam-USVI-etc)',' Honduras'],'Northamerica',inplace=True)
#SouthAmerica
train_data['Country'].replace([' Columbia',' Peru',' Ecuador',' Trinadad&Tobago'],'Southamerica',inplace = True)
#Europe
train_data['Country'].replace([' Germany',' England',' Italy',' Poland',' Portugal',' Greece',' France',' Ireland',' Yugoslavia',' Hungary',' Scotland',' Holand-Netherlands'],'Europe',inplace=True)
#Asia
train_data['Country'].replace([' Philippines',' India',' China',' Vietnam',' Japan',' Taiwan',' Iran',' Hong',' Cambodia',' Laos',' Thailand'],'Asia',inplace=True)
train_data['Country'].replace([' ?',' South'],'Others',inplace=True)
train_data['Country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Country, dtype: int64
# Northamerica    30569
# Asia              671
# Others            663
# Europe            521
# Southamerica      137
# Name: Country, dtype: int64

# %%
print(test_data['Country'].value_counts())
#NorthAmerica
test_data['Country'].replace([' United-States',' Mexico',' Canada',' Puerto-Rico',' El-Salvador',' Cuba',' Jamaica',' Dominican-Republic',' Guatemala',' Haiti',' Nicaragua',' Outlying-US(Guam-USVI-etc)',' Honduras'],'Northamerica',inplace=True)
#SouthAmerica
test_data['Country'].replace([' Columbia',' Peru',' Ecuador',' Trinadad&Tobago'],'Southamerica',inplace = True)
#Europe
test_data['Country'].replace([' Germany',' England',' Italy',' Poland',' Portugal',' Greece',' France',' Ireland',' Yugoslavia',' Hungary',' Scotland',' Holand-Netherlands'],'Europe',inplace=True)
#Asia
test_data['Country'].replace([' Philippines',' India',' China',' Vietnam',' Japan',' Taiwan',' Iran',' Hong',' Cambodia',' Laos',' Thailand'],'Asia',inplace=True)
test_data['Country'].replace([' ?',' South'],'Others',inplace=True)
test_data['Country'].value_counts()
# Out:
#  United-States                 14662
#  Mexico                          308
#  ?                               274
#  Philippines                      97
#  Puerto-Rico                      70
#  Germany                          69
#  Canada                           61
#  India                            51
#  El-Salvador                      49
#  China                            47
#  Cuba                             43
#  England                          37
#  South                            35
#  Dominican-Republic               33
#  Italy                            32
#  Haiti                            31
#  Portugal                         30
#  Japan                            30
#  Poland                           27
#  Columbia                         26
#  Jamaica                          25
#  Guatemala                        24
#  Greece                           20
#  Vietnam                          19
#  Ecuador                          17
#  Iran                             16
#  Nicaragua                        15
#  Peru                             15
#  Taiwan                           14
#  Ireland                          13
#  Thailand                         12
#  Hong                             10
#  Cambodia                          9
#  France                            9
#  Outlying-US(Guam-USVI-etc)        9
#  Scotland                          9
#  Trinadad&Tobago                   8
#  Yugoslavia                        7
#  Honduras                          7
#  Hungary                           6
#  Laos                              5
# Name: Country, dtype: int64
# Northamerica    15337
# Asia              310
# Others            309
# Europe            259
# Southamerica       66
# Name: Country, dtype: int64

# %% [markdown]
# # Label handling

# %%
train_data.Status.replace(' <=50K',0,inplace=True)
train_data.Status.replace(' >50K',1,inplace=True)
train_data.head()
# Out:
#    Age     Workclass  Finalweight  Education         Martialstatus  \
# 0   39     Goverment        77516          4         Never-Married
# 1   50  Selfemployed        83311          4    Successfulmarraige
# 2   38       Private       215646          3  Unsuccessfulmarriage
# 3   53       Private       234721          3    Successfulmarraige
# 4   28       Private       338409          4    Successfulmarraige
#
#            Occupation    Relationship    Race   Gender  Capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    Capitalloss  Workinghours       Country  Status
# 0            0            40  Northamerica       0
# 1            0            13  Northamerica       0
# 2            0            40  Northamerica       0
# 3            0            40  Northamerica       0
# 4            0            40  Northamerica       0

# %%
test_data.Status.replace(' <=50K.',0,inplace=True)
test_data.Status.replace(' >50K.',1,inplace=True)
test_data.head()
# Out:
#   Age  Workclass  Finalweight  Education       Martialstatus  \
# 1  25    Private     226802.0          3       Never-Married
# 2  38    Private      89814.0          3  Successfulmarraige
# 3  28  Goverment     336951.0          4  Successfulmarraige
# 4  44    Private     160323.0          3  Successfulmarraige
# 5  18     Others     103497.0          3       Never-Married
#
#            Occupation Relationship    Race   Gender  Capitalgain  Capitalloss  \
# 1   Machine-op-inspct    Own-child   Black     Male          0.0          0.0
# 2     Farming-fishing      Husband   White     Male          0.0          0.0
# 3     Protective-serv      Husband   White     Male          0.0          0.0
# 4   Machine-op-inspct      Husband   Black     Male       7688.0          0.0
# 5              Others    Own-child   White   Female          0.0          0.0
#
#    Workinghours       Country  Status
# 1          40.0  Northamerica       0
# 2          50.0  Northamerica       0
# 3          40.0  Northamerica       1
# 4          40.0  Northamerica       1
# 5          30.0  Northamerica       0

# %% [markdown]
# # Data after cleaning

# %%
i=1
columns=list(['Workclass','Education','Martialstatus','Occupation','Relationship','Race','Gender','Country', 'Status'])
for val in columns:
    plt.subplot(3,3,i)
    train_data[val].value_counts().plot(kind='bar',figsize=(20,20))
    plt.show
    i=i+1

# %%
i=1
columns=list(['Workclass','Education','Martialstatus','Occupation','Relationship','Race','Gender','Country', 'Status'])
for val in columns:
    plt.subplot(3,3,i)
    test_data[val].value_counts().plot(kind='bar',figsize=(20,20))
    plt.show
    i=i+1

# %% [markdown]
# # Continous data columns

# %%
i=1
sb.set(rc={'figure.figsize':(15,15)})
columns=list(['Age','Finalweight','Capitalgain','Capitalloss','Workinghours'])  
for val in columns:
    plt.subplot(5,2,i)
    sb.distplot(train_data[val],hist=True,kde=True,bins=20,hist_kws={'edgecolor':'black'},kde_kws={'linewidth':3})
    i=i+1

# %%
i=1
sb.set(rc={'figure.figsize':(15,15)})
columns=list(['Age','Finalweight','Capitalgain','Capitalloss','Workinghours'])  
test_data['Age']=test_data['Age'].apply(pd.to_numeric)
for val in columns:
    plt.subplot(5,2,i)
    sb.distplot(test_data[val],hist=True,kde=True,bins=20,hist_kws={'edgecolor':'black'},kde_kws={'linewidth':3})
    i=i+1

# %% [markdown]
# # Age-Grouping

# %%
train_data['Age'] = train_data['Age'].mask(train_data['Age'] <= 20, 1)
train_data['Age'] = train_data['Age'].mask(((train_data['Age'] > 20)&(train_data['Age']<=40)), 2)
train_data['Age'] = train_data['Age'].mask(((train_data['Age'] > 40)&(train_data['Age']<=60)), 3)
train_data['Age'] = train_data['Age'].mask(((train_data['Age'] > 60)&(train_data['Age']<=80)), 4)
train_data['Age'] = train_data['Age'].mask(train_data['Age'] > 80, 5)

# %%
test_data['Age'] = test_data['Age'].mask(test_data['Age'] <= 20, 1)
test_data['Age'] = test_data['Age'].mask(((test_data['Age'] > 20)&(test_data['Age']<=40)), 2)
test_data['Age'] = test_data['Age'].mask(((test_data['Age'] > 40)&(test_data['Age']<=60)), 3)
test_data['Age'] = test_data['Age'].mask(((test_data['Age'] > 60)&(test_data['Age']<=80)), 4)
test_data['Age'] = test_data['Age'].mask(test_data['Age'] > 80, 5)

# %% [markdown]
# # Workinghours-grouping

# %%
train_data['Workinghours'] = train_data['Workinghours'].mask(train_data['Workinghours'] <= 20, 1)
train_data['Workinghours'] = train_data['Workinghours'].mask(((train_data['Workinghours'] > 20)&(train_data['Workinghours']<=40)), 2)
train_data['Workinghours'] = train_data['Workinghours'].mask(((train_data['Workinghours'] > 40)&(train_data['Workinghours']<=60)), 3)
train_data['Workinghours'] = train_data['Workinghours'].mask(((train_data['Workinghours'] > 60)&(train_data['Workinghours']<=80)), 4)
train_data['Workinghours'] = train_data['Workinghours'].mask(train_data['Workinghours'] > 80, 5)

# %%
test_data['Workinghours'] = test_data['Workinghours'].mask(test_data['Workinghours'] <= 20, 1)
test_data['Workinghours'] = test_data['Workinghours'].mask(((test_data['Workinghours'] > 20)&(test_data['Workinghours']<=40)), 2)
test_data['Workinghours'] = test_data['Workinghours'].mask(((test_data['Workinghours'] > 40)&(test_data['Workinghours']<=60)), 3)
test_data['Workinghours'] = test_data['Workinghours'].mask(((test_data['Workinghours'] > 60)&(test_data['Workinghours']<=80)), 4)
test_data['Workinghours'] = test_data['Workinghours'].mask(test_data['Workinghours'] > 80, 5)

# %% [markdown]
# # One-hot encoding

# %%
columns=list(['Workclass','Education','Martialstatus','Occupation','Relationship','Race','Gender','Country'])
for val in columns:
    dum=pd.get_dummies(train_data[val],drop_first=True,prefix=val)
    train_data=train_data.join(dum)
    train_data.drop(val,axis=1,inplace=True)

# %%
train_data.columns
# Out:
# Index(['Age', 'Finalweight', 'Capitalgain', 'Capitalloss', 'Workinghours',
#        'Status', 'Workclass_Goverment', 'Workclass_Others',
#        'Workclass_Selfemployed', 'Workclass_Unemployed', 'Education_2',
#        'Education_3', 'Education_4', 'Education_5', 'Education_6',
#        'Martialstatus_Successfulmarraige',
#        'Martialstatus_Unsuccessfulmarriage', 'Occupation_ Armed-Forces',
#        'Occupation_ Craft-repair', 'Occupation_ Exec-managerial',
#        'Occupation_ Farming-fishing', 'Occupation_ Handlers-cleaners',
#        'Occupation_ Machine-op-inspct', 'Occupation_ Other-service',
#        'Occupation_ Priv-house-serv', 'Occupation_ Prof-specialty',
#        'Occupation_ Protective-serv', 'Occupation_ Sales',
#        'Occupation_ Tech-support', 'Occupation_ Transport-moving',
#        'Occupation_Others', 'Relationship_ Not-in-family',
#        'Relationship_ Other-relative', 'Relationship_ Own-child',
#        'Relationship_ Unmarried', 'Relationship_ Wife', 'Race_ White',
#        'Race_Other', 'Gender_ Male', 'Country_Europe', 'Country_Northamerica',
#        'Country_Others', 'Country_Southamerica'],
#       dtype='object')

# %%
columns=list(['Workclass','Education','Martialstatus','Occupation','Relationship','Race','Gender','Country'])
for val in columns:
    dum=pd.get_dummies(test_data[val],drop_first=True,prefix=val)
    test_data=test_data.join(dum)
    test_data.drop(val,axis=1,inplace=True)

# %%
test_data.columns
# Out:
# Index(['Age', 'Finalweight', 'Capitalgain', 'Capitalloss', 'Workinghours',
#        'Status', 'Workclass_Goverment', 'Workclass_Others',
#        'Workclass_Selfemployed', 'Workclass_Unemployed', 'Education_2',
#        'Education_3', 'Education_4', 'Education_5', 'Education_6',
#        'Martialstatus_Successfulmarraige',
#        'Martialstatus_Unsuccessfulmarriage', 'Occupation_ Armed-Forces',
#        'Occupation_ Craft-repair', 'Occupation_ Exec-managerial',
#        'Occupation_ Farming-fishing', 'Occupation_ Handlers-cleaners',
#        'Occupation_ Machine-op-inspct', 'Occupation_ Other-service',
#        'Occupation_ Priv-house-serv', 'Occupation_ Prof-specialty',
#        'Occupation_ Protective-serv', 'Occupation_ Sales',
#        'Occupation_ Tech-support', 'Occupation_ Transport-moving',
#        'Occupation_Others', 'Relationship_ Not-in-family',
#        'Relationship_ Other-relative', 'Relationship_ Own-child',
#        'Relationship_ Unmarried', 'Relationship_ Wife', 'Race_ White',
#        'Race_Other', 'Gender_ Male', 'Country_Europe', 'Country_Northamerica',
#        'Country_Others', 'Country_Southamerica'],
#       dtype='object')

# %% [markdown]
# # Train Test Split

# %%
x_train=train_data.drop(['Status'],axis=1)
y_train=train_data['Status']
x_test=test_data.drop(['Status'],axis=1)
y_test=test_data['Status']

# %% [markdown]
# # Heatmap for correlation

# %%
sb.heatmap(x_train.corr(),vmin=0, vmax=1)

# %%
sb.heatmap(x_test.corr(),vmin=0, vmax=1)

# %%
cor=x_test.corr()
cor
# Out:
#                                          Age  Finalweight  Capitalgain  \
# Age                                 1.000000    -0.061604     0.074845
# Finalweight                        -0.061604     1.000000    -0.011753
# Capitalgain                         0.074845    -0.011753     1.000000
# Capitalloss                         0.049980     0.007386    -0.031109
# Workinghours                        0.083997    -0.009569     0.085389
# Workclass_Goverment                 0.067745    -0.014227    -0.014393
# Workclass_Others                   -0.012100    -0.010878    -0.025688
# Workclass_Selfemployed              0.167558    -0.038130     0.083039
# Workclass_Unemployed               -0.007359    -0.005622    -0.003537
# Education_2                         0.119140     0.018334    -0.015213
# Education_3                        -0.147723     0.007052    -0.106387
# Education_4                         0.028197    -0.012182     0.028346
# Education_5                         0.109638    -0.010774     0.124061
# Education_6                         0.059830    -0.011331     0.095505
# Martialstatus_Successfulmarraige    0.278579    -0.022561     0.074446
# Martialstatus_Unsuccessfulmarriage  0.222904    -0.020048    -0.017292
# Occupation_ Armed-Forces           -0.002284     0.005423     0.000340
# Occupation_ Craft-repair            0.001394     0.010946    -0.010973
# Occupation_ Exec-managerial         0.086186     0.000475     0.060843
# Occupation_ Farming-fishing         0.029790    -0.019831    -0.002642
# Occupation_ Handlers-cleaners      -0.070441     0.016171    -0.020939
# Occupation_ Machine-op-inspct      -0.017556     0.000451    -0.027037
# Occupation_ Other-service          -0.078076    -0.009093    -0.035712
# Occupation_ Priv-house-serv         0.036665    -0.003991    -0.010479
# Occupation_ Prof-specialty          0.060654    -0.013056     0.084810
# Occupation_ Protective-serv         0.001677     0.015202    -0.006630
# Occupation_ Sales                  -0.032314     0.000863     0.003819
# Occupation_ Tech-support           -0.015333    -0.003303    -0.009961
# Occupation_ Transport-moving        0.035316     0.009636    -0.021654
# Occupation_Others                  -0.013563    -0.010862    -0.025762
# Relationship_ Not-in-family         0.018015    -0.003370    -0.017244
# Relationship_ Other-relative       -0.056973     0.019375    -0.022391
# Relationship_ Own-child            -0.414864     0.022513    -0.048998
# Relationship_ Unmarried             0.037111     0.007798    -0.028598
# Relationship_ Wife                  0.022364    -0.022966     0.016806
# Race_ White                         0.024422    -0.077322     0.015532
# Race_Other                         -0.030808    -0.068690     0.006336
# Gender_ Male                        0.080028     0.029486     0.044412
# Country_Europe                      0.023311    -0.010630    -0.002298
# Country_Northamerica               -0.016554     0.011623    -0.010076
# Country_Others                      0.006885     0.003515     0.009390
# Country_Southamerica                0.001442     0.010316    -0.008702
#
#                                     Capitalloss  Workinghours  \
# Age                                    0.049980      0.083997
# Finalweight                            0.007386     -0.009569
# Capitalgain                           -0.031109      0.085389
# Capitalloss                            1.000000      0.058572
# Workinghours                           0.058572      1.000000
# Workclass_Goverment                    0.000464     -0.021964
# Workclass_Others                      -0.004452     -0.142144
# Workclass_Selfemployed                 0.032053      0.167255
# Workclass_Unemployed                   0.006199     -0.012370
# Education_2                           -0.015906     -0.028997
# Education_3                           -0.067960     -0.121277
# Education_4                            0.043214      0.079659
# Education_5                            0.060703      0.097623
# Education_6                            0.019060      0.046643
# Martialstatus_Successfulmarraige       0.066358      0.212525
# Martialstatus_Unsuccessfulmarriage    -0.019573     -0.043270
# Occupation_ Armed-Forces              -0.004187      0.002598
# Occupation_ Craft-repair              -0.023083      0.031157
# Occupation_ Exec-managerial            0.052484      0.141918
# Occupation_ Farming-fishing           -0.015849      0.088153
# Occupation_ Handlers-cleaners         -0.017842     -0.050947
# Occupation_ Machine-op-inspct         -0.011522     -0.017701
# Occupation_ Other-service             -0.032362     -0.131914
# Occupation_ Priv-house-serv           -0.003261     -0.031497
# Occupation_ Prof-specialty             0.042609      0.059981
# Occupation_ Protective-serv            0.003616      0.015565
# Occupation_ Sales                      0.005897      0.034070
# Occupation_ Tech-support               0.003326     -0.012695
# Occupation_ Transport-moving          -0.005697      0.073993
# Occupation_Others                     -0.004616     -0.142593
# Relationship_ Not-in-family           -0.012209      0.001931
# Relationship_ Other-relative          -0.018393     -0.055712
# Relationship_ Own-child               -0.045643     -0.238483
# Relationship_ Unmarried               -0.025777     -0.043592
# Relationship_ Wife                     0.013245     -0.062872
# Race_ White                            0.019616      0.074254
# Race_Other                            -0.005548     -0.024273
# Gender_ Male                           0.045312      0.218024
# Country_Europe                        -0.004508     -0.001718
# Country_Northamerica                   0.007347      0.010542
# Country_Others                        -0.014418     -0.000946
# Country_Southamerica                  -0.004454     -0.005517
#
#                                     Workclass_Goverment  Workclass_Others  \
# Age                                            0.067745         -0.012100
# Finalweight                                   -0.014227         -0.010878
# Capitalgain                                   -0.014393         -0.025688
# Capitalloss                                    0.000464         -0.004452
# Workinghours                                  -0.021964         -0.142144
# Workclass_Goverment                            1.000000         -0.099055
# Workclass_Others                              -0.099055          1.000000
# Workclass_Selfemployed                        -0.143598         -0.091137
# Workclass_Unemployed                          -0.009794         -0.006216
# Education_2                                   -0.043851          0.031110
# Education_3                                   -0.113482          0.071158
# Education_4                                    0.058953         -0.062729
# Education_5                                    0.131843         -0.045484
# Education_6                                    0.043823         -0.019135
# Martialstatus_Successfulmarraige               0.023342         -0.075653
# Martialstatus_Unsuccessfulmarriage             0.024214         -0.001839
# Occupation_ Armed-Forces                       0.048601         -0.004814
# Occupation_ Craft-repair                      -0.076315         -0.094179
# Occupation_ Exec-managerial                    0.016516         -0.094365
# Occupation_ Farming-fishing                   -0.043885         -0.044446
# Occupation_ Handlers-cleaners                 -0.047582         -0.053224
# Occupation_ Machine-op-inspct                 -0.085076         -0.064822
# Occupation_ Other-service                     -0.015450         -0.083575
# Occupation_ Priv-house-serv                   -0.029944         -0.019005
# Occupation_ Prof-specialty                     0.203759         -0.094685
# Occupation_ Protective-serv                    0.226850         -0.036287
# Occupation_ Sales                             -0.129741         -0.089883
# Occupation_ Tech-support                       0.008262         -0.045452
# Occupation_ Transport-moving                  -0.025877         -0.055406
# Occupation_Others                             -0.099219          0.998348
# Relationship_ Not-in-family                    0.009169         -0.015403
# Relationship_ Other-relative                  -0.029381          0.016135
# Relationship_ Own-child                       -0.051374          0.130700
# Relationship_ Unmarried                        0.026789         -0.013964
# Relationship_ Wife                             0.022104          0.017086
# Race_ White                                   -0.074749         -0.017745
# Race_Other                                     0.034215          0.003939
# Gender_ Male                                  -0.038956         -0.060968
# Country_Europe                                -0.012880         -0.002746
# Country_Northamerica                           0.014184          0.003160
# Country_Others                                -0.006212          0.010920
# Country_Southamerica                          -0.002575         -0.011899
#
#                                     Workclass_Selfemployed  \
# Age                                               0.167558
# Finalweight                                      -0.038130
# Capitalgain                                       0.083039
# Capitalloss                                       0.032053
# Workinghours                                      0.167255
# Workclass_Goverment                              -0.143598
# Workclass_Others                                 -0.091137
# Workclass_Selfemployed                            1.000000
# Workclass_Unemployed                             -0.009011
# Education_2                                       0.012829
# Education_3                                      -0.067008
# Education_4                                       0.021032
# Education_5                                       0.066019
# Education_6                                       0.045390
# Martialstatus_Successfulmarraige                  0.167648
# Martialstatus_Unsuccessfulmarriage               -0.043293
# Occupation_ Armed-Forces                         -0.006979
# Occupation_ Craft-repair                          0.054097
# Occupation_ Exec-managerial                       0.102288
# Occupation_ Farming-fishing                       0.218304
# Occupation_ Handlers-cleaners                    -0.067740
# Occupation_ Machine-op-inspct                    -0.072656
# Occupation_ Other-service                        -0.047183
# Occupation_ Priv-house-serv                      -0.027550
# Occupation_ Prof-specialty                        0.028863
# Occupation_ Protective-serv                      -0.051254
# Occupation_ Sales                                 0.071448
# Occupation_ Tech-support                         -0.041911
# Occupation_ Transport-moving                     -0.014945
# Occupation_Others                                -0.091288
# Relationship_ Not-in-family                      -0.068347
# Relationship_ Other-relative                     -0.047940
# Relationship_ Own-child                          -0.088571
# Relationship_ Unmarried                          -0.046511
# Relationship_ Wife                               -0.000038
# Race_ White                                       0.082688
# Race_Other                                       -0.024567
# Gender_ Male                                      0.132591
# Country_Europe                                    0.022590
# Country_Northamerica                             -0.009688
# Country_Others                                    0.011131
# Country_Southamerica                             -0.011147
#
#                                     Workclass_Unemployed  Education_2  \
# Age                                        -7.359493e-03     0.119140
# Finalweight                                -5.622249e-03     0.018334
# Capitalgain                                -3.536720e-03    -0.015213
# Capitalloss                                 6.199425e-03    -0.015906
# Workinghours                               -1.236998e-02    -0.028997
# Workclass_Goverment                        -9.793978e-03    -0.043851
# Workclass_Others                           -6.215914e-03     0.031110
# Workclass_Selfemployed                     -9.011045e-03     0.012829
# Workclass_Unemployed                        1.000000e+00     0.010238
# Education_2                                 1.023841e-02     1.000000
# Education_3                                 8.237409e-03    -0.233920
# Education_4                                -8.056764e-03    -0.098063
# Education_5                                -6.967882e-03    -0.049250
# Education_6                                -2.628568e-03    -0.018579
# Martialstatus_Successfulmarraige            2.212088e-03     0.043565
# Martialstatus_Unsuccessfulmarriage         -6.728342e-03     0.015790
# Occupation_ Armed-Forces                   -4.760012e-04    -0.003364
# Occupation_ Craft-repair                   -9.311791e-03     0.026379
# Occupation_ Exec-managerial                -1.810162e-03    -0.050604
# Occupation_ Farming-fishing                 2.445515e-02     0.078253
# Occupation_ Handlers-cleaners               6.942445e-03     0.032173
# Occupation_ Machine-op-inspct               3.820993e-03     0.066516
# Occupation_ Other-service                   5.075775e-07     0.043962
# Occupation_ Priv-house-serv                -1.879047e-03     0.058629
# Occupation_ Prof-specialty                 -9.361868e-03    -0.060705
# Occupation_ Protective-serv                -3.587787e-03    -0.020261
# Occupation_ Sales                          -1.082845e-03    -0.044618
# Occupation_ Tech-support                   -4.494054e-03    -0.029706
# Occupation_ Transport-moving               -5.478222e-03     0.024727
# Occupation_Others                           2.525477e-02     0.030928
# Relationship_ Not-in-family                -1.480023e-02    -0.018419
# Relationship_ Other-relative                9.508349e-03     0.037551
# Relationship_ Own-child                     2.371793e-02    -0.053861
# Relationship_ Unmarried                    -8.406439e-03    -0.000019
# Relationship_ Wife                         -5.497146e-03    -0.011503
# Race_ White                                 3.071020e-03    -0.014887
# Race_Other                                 -5.538593e-03     0.011788
# Gender_ Male                                1.734083e-03     0.030272
# Country_Europe                             -3.151987e-03     0.035472
# Country_Northamerica                        6.150475e-03    -0.027639
# Country_Others                             -3.448200e-03    -0.000543
# Country_Southamerica                       -1.581635e-03     0.017251
#
#                                             ...           \
# Age                                         ...
# Finalweight                                 ...
# Capitalgain                                 ...
# Capitalloss                                 ...
# Workinghours                                ...
# Workclass_Goverment                         ...
# Workclass_Others                            ...
# Workclass_Selfemployed                      ...
# Workclass_Unemployed                        ...
# Education_2                                 ...
# Education_3                                 ...
# Education_4                                 ...
# Education_5                                 ...
# Education_6                                 ...
# Martialstatus_Successfulmarraige            ...
# Martialstatus_Unsuccessfulmarriage          ...
# Occupation_ Armed-Forces                    ...
# Occupation_ Craft-repair                    ...
# Occupation_ Exec-managerial                 ...
# Occupation_ Farming-fishing                 ...
# Occupation_ Handlers-cleaners               ...
# Occupation_ Machine-op-inspct               ...
# Occupation_ Other-service                   ...
# Occupation_ Priv-house-serv                 ...
# Occupation_ Prof-specialty                  ...
# Occupation_ Protective-serv                 ...
# Occupation_ Sales                           ...
# Occupation_ Tech-support                    ...
# Occupation_ Transport-moving                ...
# Occupation_Others                           ...
# Relationship_ Not-in-family                 ...
# Relationship_ Other-relative                ...
# Relationship_ Own-child                     ...
# Relationship_ Unmarried                     ...
# Relationship_ Wife                          ...
# Race_ White                                 ...
# Race_Other                                  ...
# Gender_ Male                                ...
# Country_Europe                              ...
# Country_Northamerica                        ...
# Country_Others                              ...
# Country_Southamerica                        ...
#
#                                     Relationship_ Own-child  \
# Age                                               -0.414864
# Finalweight                                        0.022513
# Capitalgain                                       -0.048998
# Capitalloss                                       -0.045643
# Workinghours                                      -0.238483
# Workclass_Goverment                               -0.051374
# Workclass_Others                                   0.130700
# Workclass_Selfemployed                            -0.088571
# Workclass_Unemployed                               0.023718
# Education_2                                       -0.053861
# Education_3                                        0.163074
# Education_4                                       -0.085109
# Education_5                                       -0.101153
# Education_6                                       -0.038813
# Martialstatus_Successfulmarraige                  -0.374419
# Martialstatus_Unsuccessfulmarriage                -0.137338
# Occupation_ Armed-Forces                           0.000654
# Occupation_ Craft-repair                          -0.053563
# Occupation_ Exec-managerial                       -0.103032
# Occupation_ Farming-fishing                       -0.014401
# Occupation_ Handlers-cleaners                      0.076704
# Occupation_ Machine-op-inspct                     -0.013637
# Occupation_ Other-service                          0.092212
# Occupation_ Priv-house-serv                       -0.003056
# Occupation_ Prof-specialty                        -0.082634
# Occupation_ Protective-serv                       -0.022252
# Occupation_ Sales                                  0.033092
# Occupation_ Tech-support                          -0.018360
# Occupation_ Transport-moving                      -0.040345
# Occupation_Others                                  0.131616
# Relationship_ Not-in-family                       -0.255056
# Relationship_ Other-relative                      -0.077986
# Relationship_ Own-child                            1.000000
# Relationship_ Unmarried                           -0.144871
# Relationship_ Wife                                -0.094734
# Race_ White                                       -0.018717
# Race_Other                                        -0.003570
# Gender_ Male                                      -0.106151
# Country_Europe                                    -0.005404
# Country_Northamerica                               0.028885
# Country_Others                                    -0.017062
# Country_Southamerica                              -0.016554
#
#                                     Relationship_ Unmarried  \
# Age                                                0.037111
# Finalweight                                        0.007798
# Capitalgain                                       -0.028598
# Capitalloss                                       -0.025777
# Workinghours                                      -0.043592
# Workclass_Goverment                                0.026789
# Workclass_Others                                  -0.013964
# Workclass_Selfemployed                            -0.046511
# Workclass_Unemployed                              -0.008406
# Education_2                                       -0.000019
# Education_3                                        0.049874
# Education_4                                       -0.032908
# Education_5                                       -0.034057
# Education_6                                       -0.014766
# Martialstatus_Successfulmarraige                  -0.310183
# Martialstatus_Unsuccessfulmarriage                 0.432500
# Occupation_ Armed-Forces                          -0.006511
# Occupation_ Craft-repair                          -0.045153
# Occupation_ Exec-managerial                       -0.029599
# Occupation_ Farming-fishing                       -0.026030
# Occupation_ Handlers-cleaners                     -0.015307
# Occupation_ Machine-op-inspct                      0.004843
# Occupation_ Other-service                          0.075475
# Occupation_ Priv-house-serv                        0.043974
# Occupation_ Prof-specialty                        -0.024170
# Occupation_ Protective-serv                       -0.023429
# Occupation_ Sales                                 -0.018562
# Occupation_ Tech-support                           0.028285
# Occupation_ Transport-moving                      -0.036589
# Occupation_Others                                 -0.014208
# Relationship_ Not-in-family                       -0.202439
# Relationship_ Other-relative                      -0.061898
# Relationship_ Own-child                           -0.144871
# Relationship_ Unmarried                            1.000000
# Relationship_ Wife                                -0.075191
# Race_ White                                       -0.131491
# Race_Other                                         0.013459
# Gender_ Male                                      -0.306388
# Country_Europe                                    -0.012445
# Country_Northamerica                               0.011538
# Country_Others                                    -0.010162
# Country_Southamerica                               0.013329
#
#                                     Relationship_ Wife  Race_ White  \
# Age                                           0.022364     0.024422
# Finalweight                                  -0.022966    -0.077322
# Capitalgain                                   0.016806     0.015532
# Capitalloss                                   0.013245     0.019616
# Workinghours                                 -0.062872     0.074254
# Workclass_Goverment                           0.022104    -0.074749
# Workclass_Others                              0.017086    -0.017745
# Workclass_Selfemployed                       -0.000038     0.082688
# Workclass_Unemployed                         -0.005497     0.003071
# Education_2                                  -0.011503    -0.014887
# Education_3                                  -0.033765    -0.027860
# Education_4                                   0.030022     0.030797
# Education_5                                   0.026929     0.016115
# Education_6                                  -0.006881     0.003274
# Martialstatus_Successfulmarraige              0.242407     0.106172
# Martialstatus_Unsuccessfulmarriage           -0.114557    -0.046443
# Occupation_ Armed-Forces                     -0.004258     0.007857
# Occupation_ Craft-repair                     -0.062982     0.045625
# Occupation_ Exec-managerial                   0.009110     0.051938
# Occupation_ Farming-fishing                  -0.034233     0.043983
# Occupation_ Handlers-cleaners                -0.028470    -0.014080
# Occupation_ Machine-op-inspct                -0.016552    -0.037396
# Occupation_ Other-service                     0.010370    -0.066893
# Occupation_ Priv-house-serv                   0.014043    -0.029443
# Occupation_ Prof-specialty                    0.058713     0.014542
# Occupation_ Protective-serv                  -0.025940    -0.016192
# Occupation_ Sales                            -0.019109     0.046835
# Occupation_ Tech-support                     -0.000457    -0.014686
# Occupation_ Transport-moving                 -0.039344    -0.007726
# Occupation_Others                             0.016889    -0.018142
# Relationship_ Not-in-family                  -0.132379     0.006189
# Relationship_ Other-relative                 -0.040476    -0.065179
# Relationship_ Own-child                      -0.094734    -0.018717
# Relationship_ Unmarried                      -0.075191    -0.131491
# Relationship_ Wife                            1.000000    -0.011253
# Race_ White                                  -0.011253     1.000000
# Race_Other                                    0.018747    -0.545994
# Gender_ Male                                 -0.313232     0.096131
# Country_Europe                               -0.002643     0.032417
# Country_Northamerica                         -0.015867     0.212658
# Country_Others                                0.011754    -0.099766
# Country_Southamerica                          0.004148    -0.018021
#
#                                     Race_Other  Gender_ Male  Country_Europe  \
# Age                                  -0.030808      0.080028        0.023311
# Finalweight                          -0.068690      0.029486       -0.010630
# Capitalgain                           0.006336      0.044412       -0.002298
# Capitalloss                          -0.005548      0.045312       -0.004508
# Workinghours                         -0.024273      0.218024       -0.001718
# Workclass_Goverment                   0.034215     -0.038956       -0.012880
# Workclass_Others                      0.003939     -0.060968       -0.002746
# Workclass_Selfemployed               -0.024567      0.132591        0.022590
# Workclass_Unemployed                 -0.005539      0.001734       -0.003152
# Education_2                           0.011788      0.030272        0.035472
# Education_3                          -0.040181     -0.035177       -0.021388
# Education_4                           0.011109     -0.001559        0.004871
# Education_5                           0.030287      0.023963        0.007609
# Education_6                           0.028617      0.041351        0.000565
# Martialstatus_Successfulmarraige     -0.010783      0.428030        0.018738
# Martialstatus_Unsuccessfulmarriage   -0.007123     -0.317663       -0.005495
# Occupation_ Armed-Forces             -0.004290      0.013566       -0.002441
# Occupation_ Craft-repair             -0.017273      0.225389        0.020844
# Occupation_ Exec-managerial          -0.009658      0.033046        0.019158
# Occupation_ Farming-fishing          -0.016090      0.102490       -0.011112
# Occupation_ Handlers-cleaners         0.000891      0.092229       -0.010072
# Occupation_ Machine-op-inspct        -0.006540      0.046050        0.007645
# Occupation_ Other-service             0.016939     -0.154634       -0.004743
# Occupation_ Priv-house-serv          -0.005443     -0.096904        0.009905
# Occupation_ Prof-specialty            0.030916     -0.019881       -0.006424
# Occupation_ Protective-serv          -0.003825      0.059956       -0.001085
# Occupation_ Sales                    -0.005579     -0.027359       -0.013126
# Occupation_ Tech-support              0.005549     -0.030835       -0.000672
# Occupation_ Transport-moving         -0.021969      0.133237       -0.009456
# Occupation_Others                     0.003759     -0.060880       -0.002841
# Relationship_ Not-in-family          -0.010740     -0.168957       -0.006753
# Relationship_ Other-relative          0.062159     -0.062116       -0.003756
# Relationship_ Own-child              -0.003570     -0.106151       -0.005404
# Relationship_ Unmarried               0.013459     -0.306388       -0.012445
# Relationship_ Wife                    0.018747     -0.313232       -0.002643
# Race_ White                          -0.545994      0.096131        0.032417
# Race_Other                            1.000000     -0.015487       -0.012257
# Gender_ Male                         -0.015487      1.000000        0.018997
# Country_Europe                       -0.012257      0.018997        1.000000
# Country_Northamerica                 -0.395372     -0.014677       -0.512479
# Country_Others                        0.148732      0.003712       -0.017684
# Country_Southamerica                  0.031174     -0.000050       -0.008112
#
#                                     Country_Northamerica  Country_Others  \
# Age                                            -0.016554        0.006885
# Finalweight                                     0.011623        0.003515
# Capitalgain                                    -0.010076        0.009390
# Capitalloss                                     0.007347       -0.014418
# Workinghours                                    0.010542       -0.000946
# Workclass_Goverment                             0.014184       -0.006212
# Workclass_Others                                0.003160        0.010920
# Workclass_Selfemployed                         -0.009688        0.011131
# Workclass_Unemployed                            0.006150       -0.003448
# Education_2                                    -0.027639       -0.000543
# Education_3                                     0.078153       -0.039338
# Education_4                                    -0.028279        0.017221
# Education_5                                    -0.057393        0.031756
# Education_6                                    -0.038865        0.028183
# Martialstatus_Successfulmarraige               -0.022137       -0.001599
# Martialstatus_Unsuccessfulmarriage              0.020544       -0.014459
# Occupation_ Armed-Forces                       -0.008929        0.020782
# Occupation_ Craft-repair                        0.008557       -0.016690
# Occupation_ Exec-managerial                     0.000895       -0.005923
# Occupation_ Farming-fishing                     0.022569       -0.011560
# Occupation_ Handlers-cleaners                   0.015142       -0.014013
# Occupation_ Machine-op-inspct                  -0.009607       -0.002524
# Occupation_ Other-service                      -0.014548        0.007655
# Occupation_ Priv-house-serv                    -0.012581        0.013349
# Occupation_ Prof-specialty                     -0.047855        0.036003
# Occupation_ Protective-serv                     0.017364       -0.013779
# Occupation_ Sales                               0.011167        0.006820
# Occupation_ Tech-support                        0.004544        0.000433
# Occupation_ Transport-moving                    0.011164       -0.000825
# Occupation_Others                               0.003349        0.010796
# Relationship_ Not-in-family                     0.005998        0.010030
# Relationship_ Other-relative                   -0.054391        0.045958
# Relationship_ Own-child                         0.028885       -0.017062
# Relationship_ Unmarried                         0.011538       -0.010162
# Relationship_ Wife                             -0.015867        0.011754
# Race_ White                                     0.212658       -0.099766
# Race_Other                                     -0.395372        0.148732
# Gender_ Male                                   -0.014677        0.003712
# Country_Europe                                 -0.512479       -0.017684
# Country_Northamerica                            1.000000       -0.560640
# Country_Others                                 -0.560640        1.000000
# Country_Southamerica                           -0.257157       -0.008874
#
#                                     Country_Southamerica
# Age                                             0.001442
# Finalweight                                     0.010316
# Capitalgain                                    -0.008702
# Capitalloss                                    -0.004454
# Workinghours                                   -0.005517
# Workclass_Goverment                            -0.002575
# Workclass_Others                               -0.011899
# Workclass_Selfemployed                         -0.011147
# Workclass_Unemployed                           -0.001582
# Education_2                                     0.017251
# Education_3                                     0.001456
# Education_4                                    -0.010754
# Education_5                                     0.004334
# Education_6                                    -0.006765
# Martialstatus_Successfulmarraige                0.005693
# Martialstatus_Unsuccessfulmarriage              0.007338
# Occupation_ Armed-Forces                       -0.001225
# Occupation_ Craft-repair                        0.002466
# Occupation_ Exec-managerial                    -0.006418
# Occupation_ Farming-fishing                    -0.000060
# Occupation_ Handlers-cleaners                   0.000734
# Occupation_ Machine-op-inspct                   0.015418
# Occupation_ Other-service                       0.014179
# Occupation_ Priv-house-serv                     0.020818
# Occupation_ Prof-specialty                      0.005155
# Occupation_ Protective-serv                    -0.002414
# Occupation_ Sales                              -0.016785
# Occupation_ Tech-support                       -0.011565
# Occupation_ Transport-moving                    0.004254
# Occupation_Others                              -0.011931
# Relationship_ Not-in-family                    -0.013929
# Relationship_ Other-relative                    0.037602
# Relationship_ Own-child                        -0.016554
# Relationship_ Unmarried                         0.013329
# Relationship_ Wife                              0.004148
# Race_ White                                    -0.018021
# Race_Other                                      0.031174
# Gender_ Male                                   -0.000050
# Country_Europe                                 -0.008112
# Country_Northamerica                           -0.257157
# Country_Others                                 -0.008874
# Country_Southamerica                            1.000000
#
# [42 rows x 42 columns]

# %%
i=0
for val in cor.columns:
    for x in range(0,42):
        if((cor[val].iloc[x]>0.9)&(cor[val].iloc[x]<=0.99)):
            print(val,'has correlation')
            i=1
if(i==0):
    print('There is no correlation greater than 0.9')
# Out:
# There is no correlation greater than 0.9

# %% [markdown]
# # Implementation of Xgboost Algorithm

# %%
params = {
    'objective': 'binary:logistic',
    'max_depth': 2,
    'learning_rate': 1.0,
    'silent': 1.0,
    'n_estimators': 30
}

# %%
xg=XGBClassifier(**params).fit(x_train,y_train)

# %%
import warnings
warnings.filterwarnings("ignore")
predicted=xg.predict(x_test)
print('Train value:',xg.score(x_train,y_train))
print('Test value:',xg.score(x_test,y_test))
# Out:
# Train value: 0.863794109517521
# Test value: 0.8632147902462993

# %% [markdown]
# # Results

# %%
xgb_acc=metrics.accuracy_score(y_test,predicted)
print('Accuracy:',xgb_acc)
print('Confusion Matrix:')
print(metrics.confusion_matrix(y_test,predicted))
print('Classification report:')
print(metrics.classification_report(y_test,predicted))
print('ROC value:')
xgb_roc=metrics.roc_auc_score(y_test,predicted)
print(xgb_roc)
print('Cross Validation:')
scores = cross_val_score(XGBClassifier(), x_train, y_train, scoring='accuracy',cv=10,return_train_score=True)
print(scores)
xgb_cv=scores['test_score'].mean()
print('Cross_val Mean:',xgb_cv)
# Out:
# Accuracy: 0.8632147902462993
# Confusion Matrix:
# [[11712   723]
#  [ 1504  2342]]
# Classification report:
#              precision    recall  f1-score   support
#
#           0       0.89      0.94      0.91     12435
#           1       0.76      0.61      0.68      3846
#
# avg / total       0.86      0.86      0.86     16281
#
# ROC value:
# 0.7754010088027163
# Cross Validation:
# {'fit_time': array([11.15142059, 13.63642406, 12.87302303, 13.5768261 , 12.97342515,
#         6.38441133,  5.93001056,  9.34505033, 11.18362045, 12.7764225 ]), 'score_time': array([0.0467999 , 0.0624001 , 0.04680014, 0.0467999 , 0.0467999 ,
#        0.03120017, 0.01559997, 0.06239986, 0.04680014, 0.03119993]), 'test_score': array([0.85262512, 0.86363636, 0.85841523, 0.8519656 , 0.86363636,
#        0.85687961, 0.86210074, 0.86332924, 0.86517199, 0.86148649]), 'train_score': array([0.86261261, 0.86193482, 0.86036513, 0.86309503, 0.86145709,
#        0.86217369, 0.86114997, 0.86155946, 0.86295854, 0.86179833])}
# Cross_val Mean: 0.859924673675825
